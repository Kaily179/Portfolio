# %% [markdown]
# # Data Visualization
# Data visualization is the practice of translating information into a visual context, such as a chart or graph, to make data easier for the human brain to understand and pull insights from. The main goal of data visualization is to make it easier to identify patterns, trends and outliers in large data sets.
# ### 1. Data preparation
#         1.1 Check number of words per review
#         1.2 Check rating percentage
# 	    1.3 Standardization
# ###  2. Visualization
#         2.1 Rating Distribution
#         2.2 Relationship between year and sentiment count
# 	    2.3 Relationship between month and reviews count
# 	    2.4 Relationship between rating and number of helpful reviews
# 	    2.5 Creating word cloud

# %%
#General packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
#Visualization libraries
import matplotlib.pyplot as plt 
from matplotlib import rcParams
import seaborn as sns
from plotly import tools
import plotly.graph_objs as go
from plotly.offline import iplot
import nltk 
from wordcloud import WordCloud

# %% [markdown]
# ### Importing Data

# %%
# Reading data from .csv file
Reviews = pd.read_csv("Pre-processing_DatafinitiElectronicsProductData")

# %%
Reviews.head()
# Out:
#    Unnamed: 0                    id       asins      brand  \
# 0           0  AVpf3txeLJeJML43FN82  B0168YIWSI  Microsoft
# 1           1  AVpf3txeLJeJML43FN82  B0168YIWSI  Microsoft
# 2           2  AVpf3txeLJeJML43FN82  B0168YIWSI  Microsoft
# 3           3  AVpf3txeLJeJML43FN82  B0168YIWSI  Microsoft
# 4           4  AVpf3txeLJeJML43FN82  B0168YIWSI  Microsoft
#
#                                           categories colors  \
# 0  Electronics,Computers,Computer Accessories,Key...  Black
# 1  Electronics,Computers,Computer Accessories,Key...  Black
# 2  Electronics,Computers,Computer Accessories,Key...  Black
# 3  Electronics,Computers,Computer Accessories,Key...  Black
# 4  Electronics,Computers,Computer Accessories,Key...  Black
#
#               dateAdded           dateUpdated                   dimension  \
# 0  2015-11-13T12:28:09Z  2018-01-29T02:15:13Z  11.6 in x 8.5 in x 0.19 in
# 1  2015-11-13T12:28:09Z  2018-01-29T02:15:13Z  11.6 in x 8.5 in x 0.19 in
# 2  2015-11-13T12:28:09Z  2018-01-29T02:15:13Z  11.6 in x 8.5 in x 0.19 in
# 3  2015-11-13T12:28:09Z  2018-01-29T02:15:13Z  11.6 in x 8.5 in x 0.19 in
# 4  2015-11-13T12:28:09Z  2018-01-29T02:15:13Z  11.6 in x 8.5 in x 0.19 in
#
#             ean  ...                                       reviews.text  \
# 0  8.900000e+11  ...  This keyboard is very easy to type on, but the...
# 1  8.900000e+11  ...  It's thin and light. I can type pretty easily ...
# 2  8.900000e+11  ...  I love the new design the keys are spaced well...
# 3  8.900000e+11  ...  Attached easily and firmly. Has a nice feel. A...
# 4  8.900000e+11  ...  Our original keyboard was okay, but did not ha...
#
#                  reviews.title reviews.username  \
# 0  Love the fingerprint reader             JNH1
# 1                         Nice             Appa
# 2                          New             Kman
# 3                Nice keyboard        UpstateNY
# 4             Nice improvement        Glickster
#
#                                           sourceURLs           upc  \
# 0  https://www.walmart.com/ip/Microsoft-Surface-P...  8.900000e+11
# 1  https://www.walmart.com/ip/Microsoft-Surface-P...  8.900000e+11
# 2  https://www.walmart.com/ip/Microsoft-Surface-P...  8.900000e+11
# 3  https://www.walmart.com/ip/Microsoft-Surface-P...  8.900000e+11
# 4  https://www.walmart.com/ip/Microsoft-Surface-P...  8.900000e+11
#
#        weight                             lowercase_text_reviews  \
# 0  1.1 pounds  this keyboard is very easy to type on  but the...
# 1  1.1 pounds  it s thin and light  i can type pretty easily ...
# 2  1.1 pounds  i love the new design the keys are spaced well...
# 3  1.1 pounds  attached easily and firmly  has a nice feel  a...
# 4  1.1 pounds  our original keyboard was okay  but did not ha...
#
#                             withoutstop_reviews_text  \
# 0  ['keyboard', 'easy', 'type', 'fingerprint', 'r...
# 1      ['thin', 'light', 'type', 'pretty', 'easily']
# 2  ['love', 'new', 'design', 'keys', 'spaced', 'w...
# 3  ['attached', 'easily', 'firmly', 'nice', 'feel...
# 4  ['original', 'keyboard', 'okay', 'not', 'lapto...
#
#                                 stemmed_reviews_text  \
# 0  ['keyboard ', 'easi ', 'type ', 'fingerprint '...
# 1  ['thin ', 'light ', 'type ', 'pretti ', 'easil...
# 2  ['love ', 'new ', 'design ', 'key ', 'space ',...
# 3  ['attach ', 'easili ', 'firmli ', 'nice ', 'fe...
# 4  ['origin ', 'keyboard ', 'okay ', 'not ', 'lap...
#
#                                   lemma_reviews_text
# 0  ['keyboard ', 'easy ', 'type ', 'fingerprint '...
# 1  ['thin ', 'light ', 'type ', 'pretty ', 'easil...
# 2  ['love ', 'new ', 'design ', 'key ', 'space ',...
# 3  ['attach ', 'easily ', 'firmly ', 'nice ', 'fe...
# 4  ['original ', 'keyboard ', 'okay ', 'not ', 'l...
#
# [5 rows x 32 columns]

# %%
Reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 32 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                1800 non-null   int64
#  1   id                        1800 non-null   object
#  2   asins                     1800 non-null   object
#  3   brand                     1800 non-null   object
#  4   categories                1800 non-null   object
#  5   colors                    1800 non-null   object
#  6   dateAdded                 1800 non-null   object
#  7   dateUpdated               1800 non-null   object
#  8   dimension                 1800 non-null   object
#  9   ean                       1800 non-null   float64
#  10  imageURLs                 1800 non-null   object
#  11  keys                      1800 non-null   object
#  12  manufacturer              1800 non-null   object
#  13  manufacturerNumber        1800 non-null   object
#  14  name                      1800 non-null   object
#  15  primaryCategories         1800 non-null   object
#  16  reviews.date              1800 non-null   object
#  17  reviews.dateSeen          1800 non-null   object
#  18  reviews.doRecommend       1800 non-null   bool
#  19  reviews.numHelpful        1800 non-null   float64
#  20  reviews.rating            1800 non-null   float64
#  21  reviews.sourceURLs        1800 non-null   object
#  22  reviews.text              1800 non-null   object
#  23  reviews.title             1800 non-null   object
#  24  reviews.username          1800 non-null   object
#  25  sourceURLs                1800 non-null   object
#  26  upc                       1800 non-null   float64
#  27  weight                    1800 non-null   object
#  28  lowercase_text_reviews    1800 non-null   object
#  29  withoutstop_reviews_text  1800 non-null   object
#  30  stemmed_reviews_text      1800 non-null   object
#  31  lemma_reviews_text        1800 non-null   object
# dtypes: bool(1), float64(4), int64(1), object(26)
# memory usage: 437.8+ KB

# %% [markdown]
# ### Check rating percentage

# %%
print(Reviews['reviews.rating'].value_counts())

# calculating the rating percentage
rating_percentVal = 100* Reviews['reviews.rating'].value_counts()/len(Reviews)
rating_percentVal
# Out:
# 5.0    1102
# 4.0     469
# 3.0     114
# 2.0      58
# 1.0      57
# Name: reviews.rating, dtype: int64
# 5.0    61.222222
# 4.0    26.055556
# 3.0     6.333333
# 2.0     3.222222
# 1.0     3.166667
# Name: reviews.rating, dtype: float64

# %%
rating_percentVal.plot.bar(figsize=(10,4),color='Purple')
plt.xlabel('product rating')
plt.ylabel('rating percentage')
plt.show()

# %% [markdown]
# ### Standardization the Ratings

# %%
def f(row):
    
    '''This function returns sentiment value based on the overall ratings from the user'''
    
    if row['reviews.rating'] == 3.0:
        val = 'Neutral'
    elif row['reviews.rating'] == 1.0 or row['reviews.rating'] == 2.0:
        val = 'Negative'
    elif row['reviews.rating'] == 4.0 or row['reviews.rating'] == 5.0:
        val = 'Positive'
    else:
        val = -1
    return val

# %%
#Applying the function in our new column
Reviews['reviews.rating'] = Reviews.apply(f, axis=1)
Reviews.head(3)
# Out:
#    Unnamed: 0                    id       asins      brand  \
# 0           0  AVpf3txeLJeJML43FN82  B0168YIWSI  Microsoft
# 1           1  AVpf3txeLJeJML43FN82  B0168YIWSI  Microsoft
# 2           2  AVpf3txeLJeJML43FN82  B0168YIWSI  Microsoft
#
#                                           categories colors  \
# 0  Electronics,Computers,Computer Accessories,Key...  Black
# 1  Electronics,Computers,Computer Accessories,Key...  Black
# 2  Electronics,Computers,Computer Accessories,Key...  Black
#
#               dateAdded           dateUpdated                   dimension  \
# 0  2015-11-13T12:28:09Z  2018-01-29T02:15:13Z  11.6 in x 8.5 in x 0.19 in
# 1  2015-11-13T12:28:09Z  2018-01-29T02:15:13Z  11.6 in x 8.5 in x 0.19 in
# 2  2015-11-13T12:28:09Z  2018-01-29T02:15:13Z  11.6 in x 8.5 in x 0.19 in
#
#             ean  ...                                       reviews.text  \
# 0  8.900000e+11  ...  This keyboard is very easy to type on, but the...
# 1  8.900000e+11  ...  It's thin and light. I can type pretty easily ...
# 2  8.900000e+11  ...  I love the new design the keys are spaced well...
#
#                  reviews.title reviews.username  \
# 0  Love the fingerprint reader             JNH1
# 1                         Nice             Appa
# 2                          New             Kman
#
#                                           sourceURLs           upc  \
# 0  https://www.walmart.com/ip/Microsoft-Surface-P...  8.900000e+11
# 1  https://www.walmart.com/ip/Microsoft-Surface-P...  8.900000e+11
# 2  https://www.walmart.com/ip/Microsoft-Surface-P...  8.900000e+11
#
#        weight                             lowercase_text_reviews  \
# 0  1.1 pounds  this keyboard is very easy to type on  but the...
# 1  1.1 pounds  it s thin and light  i can type pretty easily ...
# 2  1.1 pounds  i love the new design the keys are spaced well...
#
#                             withoutstop_reviews_text  \
# 0  ['keyboard', 'easy', 'type', 'fingerprint', 'r...
# 1      ['thin', 'light', 'type', 'pretty', 'easily']
# 2  ['love', 'new', 'design', 'keys', 'spaced', 'w...
#
#                                 stemmed_reviews_text  \
# 0  ['keyboard ', 'easi ', 'type ', 'fingerprint '...
# 1  ['thin ', 'light ', 'type ', 'pretti ', 'easil...
# 2  ['love ', 'new ', 'design ', 'key ', 'space ',...
#
#                                   lemma_reviews_text
# 0  ['keyboard ', 'easy ', 'type ', 'fingerprint '...
# 1  ['thin ', 'light ', 'type ', 'pretty ', 'easil...
# 2  ['love ', 'new ', 'design ', 'key ', 'space ',...
#
# [3 rows x 32 columns]

# %%
Reviews['reviews.rating'].value_counts()
# Out:
# Positive    1571
# Negative     115
# Neutral      114
# Name: reviews.rating, dtype: int64

# %%
Reviews['reviews.rating'].value_counts().plot.bar()


plt.xlabel("Ratings", labelpad=14)
plt.ylabel("Number of reviews", labelpad=14)
plt.title("Distribution of ratings");

# %% [markdown]
# ### Year and Sentiment count

# %%
import datetime
Reviews['reviews.date'] = pd.to_datetime(Reviews['reviews.date'], format='%Y-%m-%d')
Reviews['review_year'] = pd.DatetimeIndex(Reviews['reviews.date']).year
Reviews['review_month']  = pd.DatetimeIndex(Reviews['reviews.date']).month
# Selecting years that has all kinds of sentiment 
Select_Year = Reviews.loc[ lambda Reviews : (Reviews['review_year'] >= 2014).tolist() ]

# %%
# Year vs Sentiment count
Select_Year.groupby(['review_year','reviews.rating'])['reviews.rating'].count().unstack().plot(legend=True)
#Reviews.groupby(['review_year','reviews.rating'])['reviews.rating'].count().unstack().plot(legend=True)
plt.title('Year and Sentiment count')
plt.xlabel('Year')
plt.ylabel('Sentiment count')
plt.show()

# %% [markdown]
# ### Month vs Reviews count

# %%
#Creating a dataframe
month=pd.DataFrame(Select_Year.groupby('review_month')['reviews.rating'].count()).reset_index()
month['review_month']=month['review_month'].astype('int64')
month.sort_values(by=['review_month'])

#Plotting the graph
sns.barplot(x="review_month", y="reviews.rating", data=month)
plt.title('month vs Reviews count')
plt.xlabel('month')
plt.ylabel('Reviews count')
plt.show()

# %%
Select_Year['review_month'].sort_index(ascending=False).value_counts()
# Out:
# 1     233
# 3     190
# 2     179
# 4     168
# 7     150
# 8     141
# 5     139
# 12    134
# 6     128
# 11    121
# 10     97
# 9      96
# Name: review_month, dtype: int64

# %% [markdown]
# ### Sentiment vs Number of Helpful reviews

# %%
#plot layout
plt.rcParams.update({'font.size': 18})
rcParams['figure.figsize'] = 16,9

# Creating dataframe and removing 0 helpfulrate records
senti_help= pd.DataFrame(Select_Year, columns = ['reviews.rating', 'reviews.numHelpful'])
senti_help = senti_help[senti_help['reviews.numHelpful'] != 0.00] 

#Plotting phase
sns.violinplot( x=senti_help["reviews.rating"], y=senti_help["reviews.numHelpful"])
plt.title('Sentiment vs Number of Helpful reviews')
plt.xlabel('Sentiment categories')
plt.ylabel('number of helpful reviews')
plt.show()

# %% [markdown]
# ### Number of words per review with different sentiment

# %%
#check average words in positive reviews
numof_words_per_pos_review = Reviews.loc[Reviews['reviews.rating']=='Positive','lowercase_text_reviews'].apply(lambda x: len(x.split(" ")))
print('Average words in positive reviews:', numof_words_per_pos_review.mean())

#check average words in Negative reviews
numof_words_per_neg_review = Reviews.loc[Reviews['reviews.rating']=='Negative','lowercase_text_reviews'].apply(lambda x: len(x.split(" ")))
print('Average words in negative reviews:', numof_words_per_neg_review.mean())

#check average words in Neutral reviews
numof_words_per_neu_review = Reviews.loc[Reviews['reviews.rating']=='Neutral','lowercase_text_reviews'].apply(lambda x: len(x.split(" ")))
print('Average words in neutral reviews:', numof_words_per_neu_review.mean())
# Out:
# Average words in positive reviews: 42.58052196053469
# Average words in negative reviews: 76.47826086956522
# Average words in neutral reviews: 67.48245614035088

# %%
numof_words_per_pos_review.hist(bins=100, color='Green', figsize=(11, 4))
plt.title('Number of words per positive review vs Frequency')
plt.xlabel('Number of Words')
plt.ylabel('Frequency')
plt.show()

# %%
numof_words_per_neg_review.hist(bins=100, color='blue', figsize=(11, 4))
plt.title('Number of words per negative review vs Frequency')
plt.xlabel('Number of Words')
plt.ylabel('Frequency')
plt.show()

# %%
numof_words_per_neu_review.hist(bins=100, color='red', figsize=(11, 4))
plt.title('Number of words per neutral review vs Frequency')
plt.xlabel('Number of Words')
plt.ylabel('Frequency')
plt.show()

# %%
text_word_cloud = ''.join(str (l) for l in Select_Year['lemma_reviews_text'])

wc = WordCloud( 
                width = 3000,
                height = 2000,).generate(text_word_cloud)

plt.figure(
            figsize = (40, 30),
            facecolor = 'k',
            edgecolor = 'k')
plt.imshow(wc, interpolation="bilinear")
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# As a distribution of the text in a visualization way, a word cloud displays the words in different sizes, indicating the frequency of the each word in the text. Looking at the word cloud, it shows that the reviews are related to the electronic products such as: "Speakers", "Headphones", "Keyboard", etc.
# Some words are related to the customers experiences, such as: "buy", "love", "best", "great".
